# %%
# using other models via ollama

# %%
## dowonload the model in the local 

#ollama pull gemma3

# %%
# %pip install ollama

# %%
default_model = 'gemma3'

# %%
from ollama import chat
from ollama import ChatResponse
from pydantic import BaseModel
import pprint


response: ChatResponse = chat(model=default_model, messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# or access fields directly from the response object
print(response.message.content)
# Out:
# Okay, this is a classic question with a fascinating explanation! The sky's blue color is due to a phenomenon called **Rayleigh scattering**. Here's a breakdown of how it works:
#
# **1. Sunlight and Colors:**
#
# * Sunlight is actually made up of *all* the colors of the rainbow. We see this when light passes through a prism or creates a rainbow.
#
# **2. Entering the Atmosphere:**
#
# * As sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# **3. Rayleigh Scattering - The Key:**
#
# * **Rayleigh scattering** is the scattering of electromagnetic radiation (like light) by particles of a much smaller wavelength.  In this case, the air molecules are much smaller than the wavelengths of visible light.
# * **Shorter wavelengths scatter more:**  The crucial part is that shorter wavelengths of light (blue and violet) are scattered *much* more strongly than longer wavelengths (like red and orange).  Think of it like this: the smaller waves are easily deflected by the larger air molecules.
#
# **4. Why Blue, Not Violet?**
#
# * Violet light *is* scattered even more than blue light. However, there are a couple of reasons we see blue:
#     * **Sun emits less violet light:** The sun emits slightly less violet light than blue light.
#     * **Our eyes are more sensitive to blue:** Our eyes are more sensitive to blue light than violet light.
#
#
# **In simple terms:** Blue light from the sun gets bounced around in all directions by the air molecules in the atmosphere, making the sky appear blue to our eyes.
#
# **What about sunsets?**
#
# At sunset and sunrise, the sunlight has to travel through *much* more of the atmosphere to reach our eyes.  This long journey scatters away most of the blue light.  The longer wavelengths – red and orange – are less scattered and can travel through the atmosphere, giving us those beautiful sunset colors.
#
#
#
# **Resources for further learning:**
#
# * **NASA - Why is the sky blue?:** [https://science.nasa.gov/sky-science/why-is-the-sky-blue/](https://science.nasa.gov/sky-science/why-is-the-sky-blue/)
# * **Wikipedia - Rayleigh scattering:** [https://en.wikipedia.org/wiki/Rayleigh_scattering](https://en.wikipedia.org/wiki/Rayleigh_scattering)
#
#
# Do you want me to delve deeper into any particular aspect of this explanation, like:
#
# *   The math behind Rayleigh scattering?
# *   How it relates to other scattering phenomena (Mie scattering)?
# Okay, this is a classic question with a fascinating explanation! The sky's blue color is due to a phenomenon called **Rayleigh scattering**. Here's a breakdown of how it works:
#
# **1. Sunlight and Colors:**
#
# * Sunlight is actually made up of *all* the colors of the rainbow. We see this when light passes through a prism or creates a rainbow.
#
# **2. Entering the Atmosphere:**
#
# * As sunlight enters the Earth's atmosphere, it collides with tiny air molecules (mostly nitrogen and oxygen).
#
# **3. Rayleigh Scattering - The Key:**
#
# * **Rayleigh scattering** is the scattering of electromagnetic radiation (like light) by particles of a much smaller wavelength.  In this case, the air molecules are much smaller than the wavelengths of visible light.
# * **Shorter wavelengths scatter more:**  The crucial part is that shorter wavelengths of light (blue and violet) are scattered *much* more strongly than longer wavelengths (like red and orange).  Think of it like this: the smaller waves are easily deflected by the larger air molecules.
#
# **4. Why Blue, Not Violet?**
#
# * Violet light *is* scattered even more than blue light. However, there are a couple of reasons we see blue:
#     * **Sun emits less violet light:** The sun emits slightly less violet light than blue light.
#     * **Our eyes are more sensitive to blue:** Our eyes are more sensitive to blue light than violet light.
#
#
# **In simple terms:** Blue light from the sun gets bounced around in all directions by the air molecules in the atmosphere, making the sky appear blue to our eyes.
#
# **What about sunsets?**
#
# At sunset and sunrise, the sunlight has to travel through *much* more of the atmosphere to reach our eyes.  This long journey scatters away most of the blue light.  The longer wavelengths – red and orange – are less scattered and can travel through the atmosphere, giving us those beautiful sunset colors.
#
#
#
# **Resources for further learning:**
#
# * **NASA - Why is the sky blue?:** [https://science.nasa.gov/sky-science/why-is-the-sky-blue/](https://science.nasa.gov/sky-science/why-is-the-sky-blue/)
# * **Wikipedia - Rayleigh scattering:** [https://en.wikipedia.org/wiki/Rayleigh_scattering](https://en.wikipedia.org/wiki/Rayleigh_scattering)
#
#
# Do you want me to delve deeper into any particular aspect of this explanation, like:
#
# *   The math behind Rayleigh scattering?
# *   How it relates to other scattering phenomena (Mie scattering)?

# %%
stream = chat(
  model=default_model,
  messages=[{'role': 'user', 'content': 'What is 17 × 23?'}],
  stream=True,
)

in_thinking = False
content = ''
thinking = ''
for chunk in stream:
  if chunk.message.thinking:
    if not in_thinking:
      in_thinking = True
      print('Thinking:\n', end='', flush=True)
    print(chunk.message.thinking, end='', flush=True)
    # accumulate the partial thinking 
    thinking += chunk.message.thinking
  elif chunk.message.content:
    if in_thinking:
      in_thinking = False
      print('\n\nAnswer:\n', end='', flush=True)
    print(chunk.message.content, end='', flush=True)
    # accumulate the partial content
    content += chunk.message.content

  # append the accumulated fields to the messages for the next request
  new_messages = [{ 'role': 'assistant', 'thinking': thinking, 'content': content }]
# Out:
# 17 × 23 can be calculated as follows:
#
# 17 × 23 = 17 × (20 + 3) = (17 × 20) + (17 × 3)
# = 340 + 51
# = 391
#
# Alternatively:
# 17 × 23
#    17
#  × 23
#  -----
#    51  (17 × 3)
# + 340  (17 × 20)
#  -----
#   391
#
# Final Answer: The final answer is $\boxed{391}$

# %%
class Country(BaseModel):
  name: str
  capital: str
  languages: list[str]
  basic_geography: str

response = chat(
  model=default_model,
  messages=[{'role': 'user', 'content': 'Tell me about Canada.'}],
  format=Country.model_json_schema(),
)

country = Country.model_validate_json(response.message.content)
print(country)
# Out:
# name='Canada' capital='Ottawa' languages=['English', 'French'] basic_geography="Canada is the second-largest country in the world by land area, covering 9.98 million square kilometers (3.85 million square miles). It’s located in North America and shares a border with the United States to the south. It boasts an incredibly diverse geography, including the Rocky Mountains, the Atlantic coast, the Great Lakes, and vast boreal forests.  It’s divided into ten provinces and three territories, each with its own distinct character and climate.  Canada is known for its abundant natural resources, including oil, gas, minerals, and forests. \n\n**Key Geographic Features:**\n*   **Rocky Mountains:** A major mountain range running through western Canada, offering incredible hiking and skiing opportunities.\n*   **Great Lakes:** A chain of five large lakes (Superior, Michigan, Huron, Erie, and Ontario) that border Canada and the US. They're vital for trade and recreation.\n*   **Boreal Forest:**  A vast, coniferous forest that dominates much of Canada's interior.\n*   **Atlantic Coast:** Known for its rugged coastline, fishing villages, and national parks.\n*   **Prairies:**  A vast, grassy plain in the central part of the country, ideal for agriculture.\n\n**Climate:** Canada has a wide range of climates, from arctic in the north to temperate in the south.  It's generally a cooler climate than the United States.\n\n**Culture & People:** Canada is a multicultural country with a population of approximately 38 million people.  Its culture is a blend of Indigenous traditions, European (primarily British and French) influences, and immigration from around the globe.  Emphasis is placed on politeness, tolerance, and equality.  Hockey is undeniably Canada's national sport.\n\n**Government & Politics:** Canada is a parliamentary democracy with a constitutional monarchy. The head of state is the British monarch (currently King Charles III), represented by the Governor General. The Prime Minister is the head of government and leads the majority party in the House of Commons.\n\n**Economy:** Canada has a mixed economy, heavily reliant on natural resources (oil, gas, minerals, forestry, agriculture).  It's a major exporter of these resources and has a strong service sector including finance, technology, and tourism. \n\n**Key Cities:** Toronto (largest), Vancouver, Montreal, Calgary, Ottawa, Edmonton.\n\n**Interesting Facts:**\n*   Canada's flag is the Maple Leaf. \n*   It's the world's leader in crude oil reserves.\n*   Niagara Falls is one of the world’s most famous waterfalls, located on the border with the US.\n*   Canada has a universal healthcare system.\n*   It has more lakes than any other country in the world."

# %%
import textwrap
def wrap(text, width=90):
    print(textwrap.fill(text, width=width))

# %%
wrap(country.basic_geography)
# Out:
# Canada is the second-largest country in the world by land area, covering 9.98 million
# square kilometers (3.85 million square miles). It’s located in North America and shares a
# border with the United States to the south. It boasts an incredibly diverse geography,
# including the Rocky Mountains, the Atlantic coast, the Great Lakes, and vast boreal
# forests.  It’s divided into ten provinces and three territories, each with its own
# distinct character and climate.  Canada is known for its abundant natural resources,
# including oil, gas, minerals, and forests.   **Key Geographic Features:** *   **Rocky
# Mountains:** A major mountain range running through western Canada, offering incredible
# hiking and skiing opportunities. *   **Great Lakes:** A chain of five large lakes
# (Superior, Michigan, Huron, Erie, and Ontario) that border Canada and the US. They're
# vital for trade and recreation. *   **Boreal Forest:**  A vast, coniferous forest that
# dominates much of Canada's interior. *   **Atlantic Coast:** Known for its rugged
# coastline, fishing villages, and national parks. *   **Prairies:**  A vast, grassy plain
# in the central part of the country, ideal for agriculture.  **Climate:** Canada has a wide
# range of climates, from arctic in the north to temperate in the south.  It's generally a
# cooler climate than the United States.  **Culture & People:** Canada is a multicultural
# country with a population of approximately 38 million people.  Its culture is a blend of
# Indigenous traditions, European (primarily British and French) influences, and immigration
# from around the globe.  Emphasis is placed on politeness, tolerance, and equality.  Hockey
# is undeniably Canada's national sport.  **Government & Politics:** Canada is a
# parliamentary democracy with a constitutional monarchy. The head of state is the British
# monarch (currently King Charles III), represented by the Governor General. The Prime
# Minister is the head of government and leads the majority party in the House of Commons.
# **Economy:** Canada has a mixed economy, heavily reliant on natural resources (oil, gas,
# minerals, forestry, agriculture).  It's a major exporter of these resources and has a
# strong service sector including finance, technology, and tourism.   **Key Cities:**
# Toronto (largest), Vancouver, Montreal, Calgary, Ottawa, Edmonton.  **Interesting Facts:**
# *   Canada's flag is the Maple Leaf.  *   It's the world's leader in crude oil reserves. *
# Niagara Falls is one of the world’s most famous waterfalls, located on the border with the
# US. *   Canada has a universal healthcare system. *   It has more lakes than any other
# country in the world.
