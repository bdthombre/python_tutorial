# %%
import api_key

# %%
#%pip install openai

# %%
model_name = 'gpt-5-nano'

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key.openai)

response = client.responses.create(
    model=model_name,
    input="Write a poem about spine surgeons"
)

# %%
print(response)
# Out:
# Response(id='resp_0c2a5c9d690683a000692becbdad40819b9f0640210bc0eefe', created_at=1764486333.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5-nano-2025-08-07', object='response', output=[ResponseReasoningItem(id='rs_0c2a5c9d690683a000692becbe7da4819ba8989dd3c2258e5e', summary=[], type='reasoning', content=None, encrypted_content=None, status=None), ResponseOutputMessage(id='msg_0c2a5c9d690683a000692becccea9c819b849536b78ca8feb7', content=[ResponseOutputText(annotations=[], text='The Spine Keepers\n\nIn the pale hush of morning, spine surgeons take their place,\nNot with bravado, but with patient hands and measured grace.\nThey read the body’s map—the vertebrae like quiet shorelines,\nWhere nerves run as rivers under stone, patient and keen.\n\nThe operating lights bloom, a constellation on clean linen,\nThe table a sanctuary for craft that fears to hurry.\nRetractors gleam, a clockwork forest of stainless steel,\nThey trace the arc of relief with breath held steady.\n\nThread by thread, screw by screw, the alphabet of support forms,\nTitanium halos pin the longing parts back to their home.\nDiscs are replaced, ligaments tuned, a hinge inhales relief,\nThey speak in diagrams and in the language of a returning step.\n\nThere is risk, a tremor in the nerve’s thin thread,\nA moment when the map seems uncertain, the future tense.\nBut they carry the quiet vow: mend what hurts, restore the path,\nLeave the patient taller when the morning comes.\n\nAfterward, quiet hallways answer with first steps, soft thanks.\nThe scar writes a line, a map of all the days that follow.\nWeeks unfold into longer living—grace returning to posture,\nMovement unfurling like a page that remembers how to turn.\n\nSo we honor the quiet engineers of backbone and belief,\nWho lift the body toward light with patient hands.\nTheir craft is a hinge between gravity and grace,\nA chorus of care in the arch of human resilience.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='medium', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=12, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=2038, output_tokens_details=OutputTokensDetails(reasoning_tokens=1728), total_tokens=2050), user=None, billing={'payer': 'openai'}, prompt_cache_retention=None, store=True)

# %%
print(response.output_text)
# Out:
# The Spine Keepers
#
# In the pale hush of morning, spine surgeons take their place,
# Not with bravado, but with patient hands and measured grace.
# They read the body’s map—the vertebrae like quiet shorelines,
# Where nerves run as rivers under stone, patient and keen.
#
# The operating lights bloom, a constellation on clean linen,
# The table a sanctuary for craft that fears to hurry.
# Retractors gleam, a clockwork forest of stainless steel,
# They trace the arc of relief with breath held steady.
#
# Thread by thread, screw by screw, the alphabet of support forms,
# Titanium halos pin the longing parts back to their home.
# Discs are replaced, ligaments tuned, a hinge inhales relief,
# They speak in diagrams and in the language of a returning step.
#
# There is risk, a tremor in the nerve’s thin thread,
# A moment when the map seems uncertain, the future tense.
# But they carry the quiet vow: mend what hurts, restore the path,
# Leave the patient taller when the morning comes.
#
# Afterward, quiet hallways answer with first steps, soft thanks.
# The scar writes a line, a map of all the days that follow.
# Weeks unfold into longer living—grace returning to posture,
# Movement unfurling like a page that remembers how to turn.
#
# So we honor the quiet engineers of backbone and belief,
# Who lift the body toward light with patient hands.
# Their craft is a hinge between gravity and grace,
# A chorus of care in the arch of human resilience.

# %%
# response = client.responses.create(
#     model="gpt-4",
#     tools=[{"type": "web_search"}],
#     input="What is a postive news story about neurosurgery today?"
# )

# print(response.output_text)
# Out:
# I wasn’t able to find any neurosurgery-specific news releases dated exactly November 30, 2025. However, here’s a very recent positive development in the field:
#
# A team at Delray Medical Center in Florida became the first hospital in the Southeastern United States to complete a spine surgery using Medivis’ augmented reality (AR) spine-navigation system. Performed by Dr. Lloyd Zucker, Chief of Neurosurgery, the procedure leveraged AR-projected, patient-specific 3D holograms directly onto the surgical field, enabling rapid, submillimetric placement of spinal hardware. Hospital leadership noted this integration of spatial targeting, AI-driven segmentation, and 3D renderings significantly enhances surgical precision, reduces operating time, and ultimately improves patient outcomes. ([palmbeachhealthnetwork.com](https://www.palmbeachhealthnetwork.com/news/newsroom/2025/11/06/delray-medical-center-first-hospital-in-southeastern-us-to-complete-first-spine-case-with-medivis-augmented-reality-spine-navigation-technology?utm_source=openai))
#
# Similarly, in September 2025, Ascension St. Vincent’s Riverside in Jacksonville adopted laser interstitial thermal therapy (LITT) for minimally invasive treatment of brain tumors and epilepsy. Neurosurgeon Dr. Aristotelis Filippidis uses a fiber-optic laser catheter through a small skull opening to thermally ablate diseased tissue while sparing surrounding healthy brain. Patients benefit from smaller incisions, less postoperative pain, and accelerated recovery compared to traditional craniotomy. ([about.ascension.org](https://about.ascension.org/news/2025/09/ascension-st-vincents-riverside-adds-minimally-invasive-laser-procedure-to-treat-brain-tumors?utm_source=openai))
